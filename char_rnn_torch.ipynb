# %%
import torch
import numpy as np

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1115394 characters, 65 unique.

# %%
print(chars)
# Out:
# ['L', 'J', '.', 'j', 't', 'Z', 'R', 'd', 'h', 'M', 'z', 'K', 'W', ':', 'F', "'", ' ', 'a', 'A', 'u', '?', 'w', 'C', 'V', 'H', '3', 'p', 'U', 'X', 'S', 'O', 'P', 'G', '$', '!', '-', 'l', 'o', 'c', 'k', 'T', 'b', '&', 'e', 'n', 'Y', 'g', 'D', 'v', 'I', ',', 'i', 'q', 'r', 's', ';', 'x', 'm', 'Q', 'N', 'E', '\n', 'B', 'y', 'f']

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
# model parameters
Wxh = torch.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = torch.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = torch.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = torch.zeros((hidden_size,1)) # hidden bias
by = torch.zeros((vocab_size, 1)) # output bias

# %%
exp = torch.randn(4,4)
exp
# Out:
# tensor([[ 0.2012, -0.0489, -1.7867, -0.8350],
#         [ 0.1630,  1.2416,  1.2241,  1.1965],
#         [ 1.2920,  1.5300, -1.4582, -0.2614],
#         [ 1.1848, -0.8351, -1.5054, -0.8301]])

# %%
exp*0.01
# Out:
# tensor([[ 0.0020, -0.0005, -0.0179, -0.0084],
#         [ 0.0016,  0.0124,  0.0122,  0.0120],
#         [ 0.0129,  0.0153, -0.0146, -0.0026],
#         [ 0.0118, -0.0084, -0.0151, -0.0083]])

# %%
Wxh.shape, Whh.shape, Why.shape, bh.shape, by.shape
# Out:
# (torch.Size([100, 65]),
#  torch.Size([100, 100]),
#  torch.Size([65, 100]),
#  torch.Size([100, 1]),
#  torch.Size([65, 1]))

# %%
bhc = bh.clone().detach()

# %%
bh.shape, bhc.shape
# Out:
# (torch.Size([100, 1]), torch.Size([100, 1]))

# %%
Wxh
# Out:
# tensor([[-0.0130, -0.0133,  0.0111,  ...,  0.0053, -0.0075, -0.0040],
#         [-0.0089, -0.0132,  0.0011,  ..., -0.0134,  0.0011, -0.0036],
#         [-0.0058, -0.0031, -0.0006,  ...,  0.0018,  0.0115,  0.0145],
#         ...,
#         [-0.0089, -0.0103, -0.0089,  ...,  0.0111,  0.0014, -0.0015],
#         [-0.0014,  0.0049,  0.0039,  ..., -0.0014,  0.0120, -0.0073],
#         [ 0.0132, -0.0123, -0.0056,  ..., -0.0026, -0.0041, -0.0093]])

# %%
torch.zeros((3,1))
# Out:
# tensor([[0.],
#         [0.],
#         [0.]])

# %%
dWxh = torch.zeros_like(Wxh)

# %%
def lossFun(inp, targ, hprev):
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = hprev.clone().detach()
    loss = 0
    # forward pass
    for t in range(len(inp)):
        xs[t] = torch.zeros((vocab_size,1)) # initialize for one-hot-encoding
        xs[t][inp[t]] = 1 # set current input to one
        hs[t] = torch.tanh(Wxh@xs[t] + Whh@hs[t-1] + bh) # hidden state
        ys[t] = Why@hs[t] + by # unnormalized log probabilities for next chars
        ps[t] = torch.exp(ys[t]) / torch.sum(torch.exp(ys[t])) # probabilities for next chars
        loss += -torch.log(ps[t][targ[t],0]) # softmax (cross-entropy loss)
    # backward pass
    dWxh, dWhh, dWhy = torch.zeros_like(Wxh), torch.zeros_like(Whh), torch.zeros_like(Why)
    dbh, dby = torch.zeros_like(bh), torch.zeros_like(by)
    dhnext = torch.zeros_like(hs[0])
    for t in reversed(range(len(inp))):
        dy = ps[t].clone().detach()
        dy[targ[t]] -= 1 # backprop into y
        dWhy += dy @ hs[t].T
        dby += dy
        dh = Why.T @ dy + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += dhraw @ xs[t].T
        dWhh += dhraw @ hs[t-1].T
        dhnext = Whh.T @ dhraw
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        torch.clamp_(dparam, min=-5, max=5)
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
hprev = torch.zeros((hidden_size,1))
p = 0
inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

# %%
len(inputs), len(targets)
# Out:
# (25, 25)

# %%
loss, dWxh, dWhh, dWhy, dbh, dby, last_hs = lossFun(inputs, targets, hprev)

# %%
def sample(h, seed_ix, n):
    ''' 
    sample a sequence of integers from the model 
    h is memory state, seed_ix is seed letter for first time step
    '''
    x = torch.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = torch.tanh(Wxh@x + Whh@h + bh)
        y = Why@h + by
        p = torch.exp(y) / torch.sum(torch.exp(y))
        # np.random.choice stays in numpy as there is no pytorch function
        ix = np.random.choice(range(vocab_size), p=p.cpu().numpy().ravel())
        x = torch.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = torch.zeros_like(Wxh), torch.zeros_like(Whh), torch.zeros_like(Why)
mbh, mby = torch.zeros_like(bh), torch.zeros_like(by) # memory variables for Adagrad
smooth_loss = -torch.log(torch.ones(1)/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+seq_length+1 >= len(data) or n == 0: 
        hprev = torch.zeros((hidden_size,1)) # reset RNN memory
        p = 0 # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
    if n % 1000 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print(f'----\n {txt, } \n----')

  # forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % 1000 == 0: print(f'iter: {n}, loss: {smooth_loss}') # print progress
  
  # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / torch.sqrt(mem + 1e-8) # adagrad update

    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# ----
#  ("on ge ify en.\n\nCing's thim ae whare:\ninz vacusd, co doour yte sil Bote..\n\nMS Voq Voun  woutisel efeut cou harit re touk parsy hen afe thot renold\nFmive youn pele hoit I ygs hlteisu\n:pat\nthame hico yho",)
# ----
# iter: 0, loss: tensor([104.3184])
# ----
#  ("r fond: theper, wadrs: im horrs,\nOn bous wars,\ny cot thivouls:'d po,\nO that, ther hos, I:\nFBavee\nhol then\nWYentoul,\nThode sagr wire\nShove I-Yshoe goe Mabs'un! gh. ,.\nORCitMiu. Onot padme for: ho Ve ni",)
# ----
# iter: 1000, loss: tensor([80.6038])
# ----
#  ("I pfelt anderinalt firur wher nult wisis in tfont ber bulledran nerrse roodees'g at sh.\n\nLherse! fot annt bity,\nRaomr,\nAuthe notpos ther o lon.\nSeeiy bmtoorte, eremithagrl\n\nBRRINOLNI&IUS:\nBrutis thour",)
# ----
# iter: 2000, loss: tensor([67.5807])
# ----
#  ("ngibe meinoune enar iont denar it I day I\nAn\nThil Youn thot the encin ouit on hit, pize\nYol pon yourard\nCOOr cou'd ancouve fot de weath thesef hit youdiud oonere\nFepin, inouls,\nAreices\nWou che bene at",)
# ----
# iter: 3000, loss: tensor([60.9663])
# ----
#  ("worelow bourgenn:\nfeare anthe them of f. fom'd erat mope whien neame the thabe sthow non:\nWher\n\nCOave pofon: you she hove ond be you houre se tomath Hinseng,\nCeakey I takcs!\n\nSICINIUS:\nI., iy so\nd fun",)
# ----
# iter: 4000, loss: tensor([57.7244])
# ----
#  ("ars, ar\nbe aunts. RSeld: veiudn stebenge he his owtundith\nThen the shand, hir way gith he hadgarst thed Au'se eed youy nou.f\nThy ip pak.\n\nFadtcear sothrous\nSe, momet!\n fo.,\nS:\nYott hent th. Weell msfo",)
# ----
# iter: 5000, loss: tensor([56.8916])
# ----
#  ('w-ofe ary thield lrcaensomesus: herne ?omen:\nHe hits ald it if ae and wiuks bimm eisey Rerin windle hath fuesten as of alinnt\nThe nopes, Ire norsernounoe dos biet\nThis wiy, I thex,\nYou tors: so cell h',)
# ----
# iter: 6000, loss: tensor([56.5696])
# ----
#  ("y, wir yat thatn -ay veloras anheld honghe; erlet fichg bocinst ber.\n\nFor be'd at fry hat thcatas.\n\nGLANS:\nQ kaildanccure deast to kimn,siunheser\nFous;\nWith thede no whor ootol.\n\nQevr untsor! fo ly th",)
# ----
# iter: 7000, loss: tensor([57.3941])
# ----
#  ("UAEDNENYZ:\nSheurdeisg cink: nesard ande'sg.\n\nRStulart youl\n\nCLGrobor shas he wirds:\nAs urild po su so ny ou lioust\nTfoulnien hird,\nfudhe depren deild:imede leve to hotwegand ye.\n\nLABMANE\nS:\nBut carcin",)
# ----
# iter: 8000, loss: tensor([56.6824])
# ----
#  ('ors, lousso fieny tow nous bet or is see! qurnt havamest pradhed\nIr wicqul, lot lacher urisus your girdse minthe, for chonc:\nI coul noof! he\nAnd hartbe dot arl ney be lat than hay ser eis deabn lorcon',)
# ----
# iter: 9000, loss: tensor([56.5387])
# ----
#  (" youd the Thit lrey dok:\nLith of peall In the, mowshed on\nCorly uster-fort'ch thas the fat koave blourm winh wize upfeetitol.\n\nHA RiY what the hiy Shauds\nHe whe Afar cesThich, ureind bors!\nToughord, c",)
# ----
# iter: 10000, loss: tensor([55.0899])
# ----
#  ('and in setile thith coind !om thay Dleld pot my lylt atdint noinct tive;ref\nBiks thou nool heaws,\nFlele mlow setur pives, so coumaicom ongh,\nby your hor; sind dely thow; o Gwee lit and to narnday and ',)
# ----
# iter: 11000, loss: tensor([55.4418])
# ----
#  ('appuren,\nSy meim, pirevich rpzot yow:\nAn toou youle soll that Elly hevot ares I Yous? iy to soince yaw toseaigh, thrtonk, the waciy her noupess holst.\n\nHARDGEN REIUUED-Fhitheves if hay withoot\nI domst',)
# ----
# iter: 12000, loss: tensor([53.6814])
# ----
#  ("dinh haet ald lAst pryear'd arwdor ithe npood.\nSeepence'd lo sak,oWe mesh!\n\nSICHARM RSGARA BI ICHAR!\nAakr; fome tnot onelderads rire gues,\n\nBUSH:\nDe dye,\nWhewess thaule, conit mat digh ey srin thounco",)
# ----
# iter: 13000, loss: tensor([55.2752])
# ----
#  ('eb, lenteill,\nLor on batart yemoulige are\nO dis veth coanfind, riof junt to ou of tou your\nTisl das.\nOr thatsiikene cas shit dean in sand bes, hawssts one,\nAh thour in heatt:\nRhach sit.\n\nFriid Me, I h',)
# ----
# iter: 14000, loss: tensor([55.2529])
# ----
#  ("and?\nGok owrurt land yot ulEng the an me,\nAus porll.\n\nGRERTE:\nNole h verandin ar swam frot wit in ald an aingtereake Aokelf. oFd so beath, wupe feot me beich in seate cees'd sant tlettor'd Bawdtat fra",)
# ----
# iter: 15000, loss: tensor([54.5385])
# ----
#  ('ack youll! the,\nAnd it op Sousl Gid, haom her hik a und? thece,\nThat I to drpo tirepond viedes at tarfo, art soprravere,\nThas, foms\nIvernstsh hich lactinem-\nSast, me ofrings helllie ant eled wirk, por',)
# ----
# iter: 16000, loss: tensor([54.2917])
# ----
#  ("\nAnd thou souns tond cearep\n\nDUKE:\nHan wieg tobe not deigh in overont thou hur wh extrot ou durdsentt arcot he borthe dalach nocen my shis ale fy to 'od ithsse Bowcond tien? I that mn wand ath of bor ",)
# ----
# iter: 17000, loss: tensor([53.2293])
# ----
#  ('\nBENROENO:\nMis, in urou primgsunWer?\nOf heas whoun thel a tals.\n\nBENGLENN:\nGor thiend,\nAnd ben, arcutes, heak,\nI tiy,-:\nzo I werake thaul, he most Pror seade thou to theil, wame is?\n\nIRE:\nI homanst ut',)
# ----
# iter: 18000, loss: tensor([53.4103])
# ----
#  ('air, cood hey me and artoudar, Eoungh soue lisrio font! in the enous the, linsoat.\n\nN EOLO:\nCIdrey leake greisde mle be eses, fanef, amqaty, lith wile scmeves in paill art my oo gish aacay ques made; ',)
# ----
# iter: 19000, loss: tensor([54.5846])
# ----
#  ("s ve mull read hime am fin.'Be firw, dolforse blirk hath be thot band, guel Any and ho givese.-:\n\nULETI:\nHeodny line\nGor;-dy?\nSuot ins hom.\n\nNROTUMEO:\nO Rlatheres ald ssuice herd at ig wo ease lied th",)
# ----
# iter: 20000, loss: tensor([54.0128])
# ----
#  ("l ther-dhay bling,\nMemy not fargen:\nAt and bigy' eoyesbe;\nUfomlang, then mling dyecpare, rovy, onlowgarl. RO bun ny in seporreuld in node. ban,\nSe foore; Aust hisst of prey nist; chot thed\nThe the wea",)
# ----
# iter: 21000, loss: tensor([54.4929])
# ----
#  (" lolh shash and hange my me witt:\nI dorhilgen's In Op.\n\nULEMET:\nThith and the ncoudge!\nThired eawr ryot\nIre deas, dor dald ne aldcolve,\nThe coust\nBo to mar frurst sweithle er wied,\nI wow, wive, J 'Ath",)
# ----
# iter: 22000, loss: tensor([53.1332])
# ----
#  ("ESAPRA\nTIET:\nTheeve,\nTo the virent is by\nFo hath we, is to I the havime, they, thirss my the lliseur that erer shele my mo deacke'd thus?\nPivesefiesncangws herbn allar aist that that wisen\nTom sitiace",)
# ----
# iter: 23000, loss: tensor([53.5411])
# ----
#  ("d, I hath cinger:\nDoues, this\nThou mpoefarn!\nThatl yet; upith, I mpes not and thou, of some ithor ciok tead:\nAnd ford, cime' ?fom orh bremart blotore Wiss!\nBrno tore'. feors hid lod shis whe lrospp ci",)
# ----
# iter: 24000, loss: tensor([53.2844])
# ----
#  ("d,\nWhe.\nGsuet munce is wy thith twak boy muner woll chang 'thy halp a ware be ant we a duns thy caly noust,\nWhe the mawe plowe dote.\n\nBMICHYEN KI:\nI Touncand: dat thes:\nBur owith blou's thou sle slapl",)
# ----
# iter: 25000, loss: tensor([52.7675])
# ----
#  ('f thou ming teastsear, wimndeck.\n\nQFavry.\nThe hagrest play now cly Lingashand a prrtorrbet on my aris thriss, wIcht to to len;\nAnd the bee sull ele oF ind Hy fremye, Your sthith:\nWhandink deak: mered ',)
# ----
# iter: 26000, loss: tensor([52.1551])
# ----
#  ("u I're shaissper hivant,\nThere forkery apllor wher.\n\nHIN! ERDA:\nSoth mowris thy loet froth, withipt thit Id datre lithibe in by, end Efrevack the co itare come seworld wath me, ir fliy grtart frish!\nG",)
# ----
# iter: 27000, loss: tensor([52.0068])
# ----
#  ("RLGCERS:\nWear thees! ferarthis in thip baren, massit me,\nAnd froll wich your me wath sick wis sterteruigtssen'lise,\n'se!\nWe thot hovese\nMoricnend:\nCond telou, of ande and mife; I's.\n\nARDaven,\nFle ging",)
# ----
# iter: 28000, loss: tensor([51.8898])
# ----
#  (" prom?\n\nYARK:\nNaosunt srotfor:\nIn\nWakrom thas'der bloee,\nMa, that\nShothe he wingte, a aptir henT-gar lordyand for whither,\nYoust, hursersst!\nWhourtand yol bow, riint mores wand he ageast, comesiy! sar",)
# ----
# iter: 29000, loss: tensor([53.1809])
# ----
#  ("S:\nSow.\n'le by youm, hup wy and sut, O\nPno ert ai hene\nIf laed, is I hang mane mor, cond if the arce?\nOn on freild,\nBs the doord, I'rd\nNos!\nFor he\nFy nitt seat wich ray vy then shen ie\n\nLORD:\nMat crei",)
# ----
# iter: 30000, loss: tensor([53.3329])
# ----
#  (" seatre!\nNoust. I'ls\nAnd and malt,\nY mby, pureuy mat strilt le wo I hatrs; ale baom the verh, hell.\n\nSomthand and lit my rive sear my! whaigh loven it drow;\nYour, of I wiky la; mose'd be\nIis I'ledsues",)
# ----
# iter: 31000, loss: tensor([53.6230])
# ----
#  ("lo: mamy, meee mupfered, sullnoud he, it ay, lot; but butn hed to a'd of\nSo gust farsenouls pucteght thearter seam!' he elie, Of gren thay my; and mall\nCome and.\n\nF.\nIM ILI: Leme\nSome offen whow, her ",)
# ----
# iter: 32000, loss: tensor([53.5751])
# ----
#  ("evenous the weme linge tutof my aboake\nDo bickeirss!\nFor yould:\nFean mave wo, mine bomshantes make wher to m, hices: prike\nAnd ane ithal;\nShant, mnge ower\nKidy,\nLernonke ing, in you, hit;\nI heell's my",)
# ----
# iter: 33000, loss: tensor([52.7839])
# ----
#  ("I comnol ane buty, To chat sirtit leisth urake, b an youse to demvowe ghands. eren\nGo s alonce to ceeciettever noner me pfut ki lichery siblice the by bed not is you, hith's deo,\n\nMaljom forsty me hac",)
# ----
# iter: 34000, loss: tensor([52.4575])
# ----
#  ("corlbank, a with at's you, the youer her thou Fraindns os you steave at the nockey a vere o thy yousule Vone you hapsird.\nHoun argo'd the have be 'pomt hos- trive thind but'do soouy you dosiow\nAnstens",)
# ----
# iter: 35000, loss: tensor([52.8308])
# ----
#  ('or:\nIn your thaald.\n\nLINLO:\nWory\nAnd, ant allis was, is. that ar mery\nA I mallonged my nid\nIr you me.\nHoth sil dow dotil!\n\nKOCESI:\nNoMer on se, and soinseave fety is\nAnd you ad thitilet:\nBighet,\nAvake',)
# ----
# iter: 36000, loss: tensor([51.8293])
# ----
#  ("lw, be you it and ave art Ant leom; wath dten yed oow a wit share you a dove thart.\n\nBANESCyO:\nYous ab'd weplliving fom mandeemay shis\nshe frot gredoraolf hom is aris,\nIsers.\n\nLUSThADABULWAR:\nAnd shou",)
# ----
# iter: 37000, loss: tensor([52.2895])
# ----
#  ('!\n\nIUKETIO:\nHes he wonger verid, thasef wourd to usouss it anget nother, hart ufciel iny our a hivel coshenes, as a wpeant:\nLother do his it cantend delvatispels he brenect chet listh san.\n\nTave danen',)
# ----
# iter: 38000, loss: tensor([51.4668])
# ----
#  ("gk norf wore my thal peath, an\nAf thour no mes.\nHort? now webregdll.\n\nA:\nYour hoce's ind hart 'blaghurs:\nI rent ond sarr be arby\nfot to reall my may thot comed put at kier an most to beir veill in cad",)
# ----
# iter: 39000, loss: tensor([51.7732])
# ----
#  ("s mon of\nthis fis tase, mortor progeesmy\nin tor won parep\nMasterh, my bed kry had, ano sateir a do shiesei's you repay nous see the read aly Bult coth jukres but we thet and, fy me semy ver laknows! M",)
# ----
# iter: 40000, loss: tensor([52.6966])
# ----
#  ("ith taghur lol and delt we, youcoret.\n\nKENTIO:\nThimon:\nI; Sinjiglay not miring, peate.\n\nKENTESA:\nGost's rew.\n\nCiTh her, cabeess wis to hlla coucermay summis.\n\nOLA:\nHerch.\n\nLARINCSA: Durls li tame hadl",)
# ----
# iter: 41000, loss: tensor([52.2120])
# ----
#  (" day, here's lest is! tread a wringiint lave I acrage empnepuld coma.\n\nShaby wath hithaurediind, comlie sinm Intiy hawithe for mow sered and greim aw a Cithe-\nThop chorlend an?\n\nCEPRUS:\nPow?\n\nPIIHIO:\n",)
# ----
# iter: 42000, loss: tensor([51.5938])
# ----
#  ("erblom polledn\nLor sentteilsar mich his, the that in, on chow sir baus,\nBostconled sin hertige'r here:\nI and and of o\nFir heer I be wan na wardsent, wone woulsel aplden be,-:\nTiouster, that of and dis",)
# ----
# iter: 43000, loss: tensor([50.4654])
# ----
#  ("owh with.\n\nSIPIO:\nI if eftarp he por:\n\nHUCSTRUCEPENThORO:\nWhow't\nTatint desing itecs it they prich yow the sim and mat; dopiace,\nLoll hrame\nsing thou k-ben my.\n\nTRUCHCRANE:\nTor vwo, quat apave bustad ",)
# ----
# iter: 44000, loss: tensor([51.9222])
# ----
#  (' mnet bo!\n\nMVONSTUS:\nBay urles of a maigatiig wiel to the nousd Is there.\n\nHoUMENT:\nTrave wemeank\nI; our kirss,\nWheust wour youlter, rod nepand you aer?\n\nHENIOT:\nWhe loantetonk me?\n\nUoMIS:\nAo sin in r',)
# ----
# iter: 45000, loss: tensor([52.3964])
# ----
#  ("d-fooll!\n\nVALUI, I, I my heren:\n\nHaRULUM:\nToust:\nLour?\n\nTave wit; bute:\nMeemsing.\n\nBACcINRUSANIA:\nIs. de s! I pimet ous,\nCrake,\nI hor hee ninesmeve I're rand bugts prompe the pure tirtinserss peid, wa",)
# ----
# iter: 46000, loss: tensor([52.5336])
# ----
#  ("MICUD:\nRithers have that my i's timely ont hich our om gell frane,\nHath Wandele Bithar witumer not fore thou to you he poulis:\nWhen hene grecondove bee, woand!-\nVINTIONIS:\nMoncwen becIne tull 'Meers, ",)
# ----
# iter: 47000, loss: tensor([51.9480])
# ----
#  ('toomep wiutss\nKs hatingend,\nI bohst my the carsw,\nCorize mat ben the mangI, thou,\nWhe thet, urt is llieing deom- osh, lut,\nUor pretime my the theing nat.\n\nBRIVANUSIUS:\nThith uld bud the preokl coust w',)
# ----
# iter: 48000, loss: tensor([50.7826])
# ----
#  ("ller nis presby thaned:\nDit it thou aud thee hime in ronen gle seren: his seal with by,\nSo; hill faich' abzen bus\nsuljunst\nWhats sad bust youstor home daves?\nIy ble Se heinn you wOre Mathes mace ta gr",)
# ----
# iter: 49000, loss: tensor([50.2765])
# ----
#  ('end this that the pow uncelv rost sont then harsen heve fort touldle shithe:\n\nMeme ave hingire some, eld but hose, I but not not you fare chor be makn with nost of seld, io, hath of weal:\nand,\nAnd we ',)
# ----
# iter: 50000, loss: tensor([50.5948])
# ----
#  ("ee the bforoll whe seruty you arhest is manserecy cadry, men't there oul shund the javas, wllos towron; all\nSome sunst\nHall'd mensoy, do .\nSheldcol.\n\nSINIOCHNUMNIUS:\nSor as an the wrecan.\n\nTRUS\nMYUI'S",)
# ----
# iter: 51000, loss: tensor([51.5908])
# ----
#  ("and\nThey stest acdirnt, go carich and greviy riith thet thy lor? cders!\nWepler gracen the do binm thil benould lorn charke that it with hear cIyal this, chus I will have mat'n you thing mlaild thom ch",)
# ----
# iter: 52000, loss: tensor([51.3900])
# ----
#  ("oven;\nButce fran on be Sust thou?\n\nFAlinspar that that\nmy If prath conouch kser, woures, I strow'd futher!\n?\nMast dooke he wife ciel lakre prome he go thears of you strall:\nYou, is ssther!\n\nKVIARETELA",)
# ----
# iter: 53000, loss: tensor([50.9755])
# ----
#  ('hauler I thes intester buthorsond gomy may in my to lomellerss,\nTerwire prenous doll a\nFirlluish the beelt loke hadl dighe: our bedro Btruebly, that apnd I thou than o dooing, wang palls losere the le',)
# ----
# iter: 54000, loss: tensor([50.4422])
# ----
#  ("ss's ince, in'se.\n\nHANGINSs:\nThes:\nIn lot the bowferd;\nTo sitluco dais aver; sunstca thes Wich lord yite\nfole to to kviold,\nYou to and rech and crontacoulvecwing,\nWe at dath thitize tyout mate to 'ter",)
# ----
# iter: 55000, loss: tensor([50.4101])
# ----
#  ('le, dath y, an stues\nKowize cane ront,\nAudfay to the perave buss;;\nThe decterboncw frode goor dend fothing tilut.\nThe suak beig thay meren Ledenon tadbu.\nWhor frorl in camese.\n\nQhurd gither hank wep a',)
# ----
# iter: 56000, loss: tensor([50.2587])
# ----
#  (" thou sear!\nAmy supoustit, theyr thou cho.\nBuew, frat hath is mads?\n\nKING EDGGllowllore ous ant dor, ier croter o\nPlorn bus forpasl'd tobes to beaks, lot I comy and Tivitnore denss my has, knut\nI, sue",)
# ----
# iter: 57000, loss: tensor([50.8726])
# ----
#  (" sournt so noke ammad wkibe you wingur:\nAnd noseny'lt ould I lith deme and upugmare thind thilk my; nousee hall:\nMeath blom I daut then er'd mut:\nTedme!\n\nKIthis exalm.\n\nMINBSANEN:\nWheme I the cardart ",)
# ----
# iter: 58000, loss: tensor([51.8106])
# ----
#  ('hech my toll\nOn to,\nbasherst beems and beth, thame,\nFrepprowar worspesene sseniansh in gor how shaine ouce nighen\nAnd sonesis mleast o cale thein tuven swat hast of thouinghe,\nPo prise?\n\nALERD ERRY:\nO',)
# ----
# iter: 59000, loss: tensor([51.5688])
# ----
#  ('athers ixo,\nWhat not to:\nAear you thy efsoadcl-be shfun sondiy dife thick perveicet, boy The andeld the pros tad,\nNoks;\nBor: peaks, thur wroke my spriefeanne.\nBemsery, Sube soret a frit gence shat all',)
# ----
# iter: 60000, loss: tensor([51.4201])
# ----
#  ("seave ming wrooust on?\nThack: kines of my unceed as, telreather theel,\nHorves I'I noge juatent bighere's this thir with me;\nI mound' knot Role a king king lemt\nBhas'\nCall figrease bust?\n\nWORDY: I you ",)
# ----
# iter: 61000, loss: tensor([51.1757])
# ----
#  ('ss.;\nReat: neatintious are worr nnaldy sakers a it butt I sers, I cenere didr, on weery pay, oll the tales offull parksury yow.\nTo and the it on ence irear, inlen jund peang wole vable tues ugoof mong',)
# ----
# iter: 62000, loss: tensor([49.6509])
# ----
#  ('ane rid shnst alietreiy in gro se waw wador not mace do I wary whokety, I nitiusp; our wath hauntelfercendy tack noughury chamusu, that sofing bein.\n\nMEROCB:\nNo frill the ank vicke gris, ce\nNot has mi',)
# ----
# iter: 63000, loss: tensor([51.0815])
# ----
#  ("gesment.\n\nPROULGAKE:\nId it I!k:\nCours.\nDeall Roof nop'd ape bavin. Lever, fome:\n\nSINGEEN OUCHER:\nAvee sertes' pest camartazendreng male nod, diat thot aring youk coutin: is, wit.\nConther mime as alk-g",)
# ----
# iter: 64000, loss: tensor([51.1162])
# ----
#  ('ct, I hant mane.\n\nBRONEEL:\nThat the pay for is bunt hacctar-fine! ble madderde so,\nThes they were spex ge ucoy I crinoul, the ame my love ad I beant not miin paes oul hong:\nOf, wnottloy you dided it t',)
# ----
# iter: 65000, loss: tensor([51.4816])
# ----
#  ("I hich LA stof berd; brome qoave, the sy in for fare head, of tho, by some.\n\nGBlaly's, dong, rend Taing ny in!\n\nJULELI IO:\nIstess liakich with and hing-a my by'lis sle how:\nItey save:\nThyels,\nWive, wh",)
# ----
# iter: 66000, loss: tensor([51.2063])
# ----
#  ("ty,\nO;\nA'd weven, asa:\n:\nBoous arr mould in weull suca ta, gstod urnenccon is cuch she puty You cous and o rin dodlt'd's a trose nall, souse oF hald,\nBud's Juop be: Afiet shall the Go deay monif theal",)
# ----
# iter: 67000, loss: tensor([51.3505])
# ----
#  ("pore ut illfy.\n\nPUCELYO:\nThow spartlly?\n\nGPUCESORY:\nBok. I wors,\nRave hou:\nThis be, shap's with te aft gree wild ceas;\nThe buthant you deacp.\n\nDUKE:\n\nCOLE:\nWhere, and of to grown.\n\nCANRARO:\nBevry, fow",)
# ----
# iter: 68000, loss: tensor([50.9881])
# ----
#  ('t\nCarpt tiven vave whim sturs inough,\nAnd in ondewle unther in onchous ond and ot thes.\nTiad un, und, nok bus outhy.\n\nRARCORK:\nWhen the plide ratielf in to woak, that beg kner wimg,\nWho, thy be Heal p',)
# ----
# iter: 69000, loss: tensor([50.9817])
# ----
#  ('r savew-wnoty.O\nFotheinns nother ing,\nso my mey sut king mors!\n\nLABRII:\nWeet, bow\nAgtemoun?\n\nLARRY:\nnow im rid.\n\nQUMUNELBOD:\nRhue!\nWhis and on thicou the costlainvow sajt unCltuloniphill yenord pis la',)
# ----
# iter: 70000, loss: tensor([50.3804])
# ----
#  (' eate:\nEs\nOr his frot the pere wither in my,, the tere, hewrialdect ibly, me sued.\n\nBIFTEY:\nAnd dome now hath have from this. Or his speevlere soy pory Paik am?\nThet insir.\nAnd And,\nWeam benet ond tow',)
# ----
# iter: 71000, loss: tensor([49.9227])
# ----
#  ("ce of thou hawgur lor of pronst brore I panen, hat magut ofrend I jonder remorwer to,\nAt'te.\n\nSINGGY:\nA oudrent, afow dome chIy swanow and le,\nThe deamt in 'o hate hedruened\nLol and in aldess wich to ",)
# ----
# iter: 72000, loss: tensor([49.7006])
# ----
#  ("en and and vilt ito growshs, wich fo the dasWarek gain the bathald concele jous ad lese'd his -on fien, and wencortte! hath his wrur, detenoust,\nJust then tidike an this no chas 'thole! the pros's,\nAn",)
# ----
# iter: 73000, loss: tensor([49.4927])
# ----
#  ("aunssen of blose: fo crist when our a wir I bat rentetret with wedtaly: will twer more,\nI'st pwerand the at my whur yot my bith histt cart ary, froad, you beir whe be.\n\nGrryeibind wall gow lall ce Po ",)
# ----
# iter: 74000, loss: tensor([51.1524])
# ----
#  ('ow howro O rromender fero an en bunusfe,\nBy sink.\nWhese:\nThat stebour swom all,\nEive the curidfury not and thas and thy to hear:\nSuch I shangar\nYour by So Eofece hiclunss avirgarges busenchy a ccating',)
# ----
# iter: 75000, loss: tensor([51.1763])
# ----
#  ("o my eeess ot a'ch,\nTo mank\nby shis\nQreen hop bust naist I a mate care.\n\nHINHIOLS:\nAn sherear so blost wher; fousthy thack rie a medy he?\n\nQUCEOTLI:\nARIds thatlee agres moch dare her Fmink-bo iidt rey",)
# ----
# iter: 76000, loss: tensor([52.1089])
# ----
#  (" featiind!\nOf hor\nI wave'ch fiver ht a Fstrence a wait blond as woll doent when forf to deard:\nWhof tooteess g massers yet he shalinges herst sone'gedrirsuevild lope, morus.\n\nLARCKIXY YOLAS:\nLor have ",)
# ----
# iter: 77000, loss: tensor([51.2714])
# ----
#  ('n,\nThe of as cemono, swore was coras thy pogour bee of the eed Gok, ans comkpon.\n\nCLIOLES: I hyore therion you spower wsod there on as. Our me were you:\nfon,\nYat mase the tile\nBs her bes sing:. Camblt',)
# ----
# iter: 78000, loss: tensor([51.0385])
# ----
#  ('choover\nThy cole sop\n\nMIRSSthit frener meinth so I\nI lik; cacr in fipelpom:\nAnd bitemnden.\n\nPUIUS:\nYourds alves wise wherented reaty yat live dome offor pirck\nHifd that for prat abese\nCichernngt. hid;',)
# ----
# iter: 79000, loss: tensor([51.0522])
# ----
#  ('as comauve of trens yad ad fow bistey olr eerspel lorgentiar: with I vrot bat then Comit: to, burd my can, shaupseles thou that?\n\nALIZESLALE:\nYoushs,\nOnst, and teir sun he the got -iole it Wicro?\n\nBIZ',)
# ----
# iter: 80000, loss: tensor([50.5807])
# ----
#  ("tead tueth ornt nod a king\nbe singiray aar qoth it adw.\nOfe,\nBy noono ming, a tinn'd your weak hath dey?\n\nMEABETO:\nI'red a wid wighy bew tocepeflit awered to sprevet with ank fet ammandes?\n\nFrave sirc",)
# ----
# iter: 81000, loss: tensor([50.3119])
# ----
#  ("er-ble if\nHas thesk hy a yo-, Coutst hich ewy bat. of with whe onn.\nThad the ist.\n\nANTE:\nDuth feed unmang boont air hath that, for pristlied onoll onl upelpay mase's\nAd buill himprsife tast you goothi",)
# ----
# iter: 82000, loss: tensor([50.1938])
# ----
#  (' bespast hy ad the rricetter al her mel but of wimparlt\nCamfer slelt for you and umpentlem kreakne my panculy recetst\nPrands while pread a doringe thou rey my the blich cersair stamon moo I a me; jo r',)
# ----
# iter: 83000, loss: tensor([49.1022])
# ----
#  ("maw ppead pelave thoul, gaik yould undilorem'd the wfo hito vit sillowc:\nHis for on: caath, saling\nWhy, am conce I comy fow you hath conr thy lrot in sluting.\n\nSurthelje wirse's lome\nWead not bealiny,",)
# ----
# iter: 84000, loss: tensor([50.9365])
# ----
#  ('ult, me wither kiunt berw:\nMarkikesseco till.\n\nHANTI:\nMyss friel one\nso.\n\nBANTIO:\nIing\nThe Kay us; my bold; wese and grysses! I till a whereawiy. Lond undica of do we havinn be verrauleapprietsllee my',)
# ----
# iter: 85000, loss: tensor([50.8176])
# ----
#  ("s! Hagcier frissin.\n\nPATLARD VIO:\nTo, shele of whol-\nAP:\nPirk'd you pered you as so thind, not hath if netla for thinn hath thou thime, sto? I my sernt ladl, an weursuring seakoarief'don:\nBacise by wo",)
# ----
# iter: 86000, loss: tensor([50.5135])
# ----
#  ("y my meeted tood;\nhe keppore sep'lave tore thumes proteast you nothan'd townt\nTo fath, thee\nI soo,\nBico\nA walarstsiguold,\nBuke werw yot ne knese hereittsor soy of surpy ithas, dier\nA:\nWhim? brize,\nBut",)
# ----
# iter: 87000, loss: tensor([49.9080])
# ----
#  ('TIO:\nBoads I sham the bed yot\nAs and kicty switwen?\n\nNVINCENCTIO:\nTo and alt must andery.\n\nOSTO: I where\n\nBACANCHOMNARA:\nHas serove fren you willsent,\nWhen wienanted me as-stirgy, ury nour begit buty ',)
# ----
# iter: 88000, loss: tensor([49.6321])
# ----
#  ("o ond frotume we haik And then tho, theyk o heruchanoblet spold, the Hene me rees mat:\nLe.\n\nBEPTO:\nPfave.\nAnd fist tieven's bess,-:\nThat\npronju.\n\nASTIO:\nWhither prist a meentcant promive olp, thick,\nF",)
# ----
# iter: 89000, loss: tensor([50.9696])
# ----
#  ("all when he gry shase; dich shy, and whanger hat.\n\nTUATHANTIO:\nBith state of serve it blos?\n\nSILRENCIA:\nOna,\n\nVISGUTIINALO:\nSo stour, whol tith.\n\nVINALO:\nAny to baild!\n\nGrokaN!:\nIn\nG I'Tr shathour; ho",)
# ----
# iter: 90000, loss: tensor([51.7700])
# ----
#  ("ost.\n\nAMIUNESA:\nYou on hink be goud mue ervelle To tile then lious; allert: be have onkiny. My, thy, to and hith,\nAs make, worp\nBas cked his ongiens oone whouss--I';\nEf me the fould utter grinesine\nOS",)
# ----
# iter: 91000, loss: tensor([51.2549])
# ----
#  ("LUS VIUMGCUS:\nI wherile he iblioway, twar win that tutily lipiy icoud praiep.\nEves have de sinm.\n\nTRUNUS:\nYourd it, bait'ck ho to carly. Cwarss heae hild, hat a wret this herisowell-weat and ity,\nUnal",)
# ----
# iter: 92000, loss: tensor([50.0130])
# ----
#  ("o hir candovan, sust nos' pripsensist puchive;\nSies, with he.\n\nPICIO:\nSid thas lisis: by perster apile fropfer tord pleven hiast,\nYour noses monelf, there,\nSeach.\nThe hir grot.\n\nROMENELANUS:\nWhat all ",)
# ----
# iter: 93000, loss: tensor([49.1947])
# ----
#  ('HANOLUS\nBSINA:\nBut ham turpert.\n\nBIUS:\n\nBIOLUS:\nHems mas, sith ant\nMes thlift neavecensind bee, litel ast\nIf sworns\nSaow Swat nik my me the wnaw he all have sesen, youl le she in, iw vulliat he conith',)
# ----
# iter: 94000, loss: tensor([49.6619])
# ----
#  ('codith and\nATky? Low ghat tir ounsurs.\n\nFFile,\nhom.\nBut vobubent then the mast,\nAmve Kusene!\n\nNurd,\nI, herh sivesbe,\nMither?\n\nPRISllonur bres not pored and orsisa Thite,\nI bued, buten con.\n\nRIANIUS:\nF',)
# ----
# iter: 95000, loss: tensor([49.7532])
# ----
#  (" maspeed afm, but?\n\nLEMANDO:\nThe 'sew must in hill yound vigel,\nHentetiy'd onds I care'd thy sore coint Madceoul thet you lowiy sours think?\n\nGLENENEN:\nThe Spies I ther raty, gow\nweir.\n\nMINTIIUSU:\nI t",)
# ----
# iter: 96000, loss: tensor([50.3417])
# ----
#  (" oud cons enquek\nYous pallove sughs the be; I whar, Tory\nFive be, cornead fost he bethike your home'd Comitht rost, heust\nTo me,\nAnd a may the:\nSise thered studad werus me to lid yout thake mlots,\nBy ",)
# ----
# iter: 97000, loss: tensor([50.2745])
# ----
#  ('e sharges, dutold iffeild,\nYou cam indice notlepze rwild doldon uh lord poly medge;\nRenhart he had shall theig, by my thte.\nNo rewt is was as to grotick weve beme libterece you of streatcangs:\nHin, o,',)
# ----
# iter: 98000, loss: tensor([49.8887])
# ----
#  (" lor there;\nAut my, shend lobe, lord kpeine wroty hilk\nThe, male your clust I he come mont 'tear of love thit sto for you mangul, recerled erleghenseen, foongest.\nYon cly.\n\nGLENCESTESTO RAMEHANDIS:\nAr",)
# ----
# iter: 99000, loss: tensor([49.3460])
# ----
#  ('r sendringest. may Torct:\nOn with.\n\nDUKE NoRIZAS:\nI Cars inders my rainsanco is\nArace, I my?\n\nGLYIA:\nBur Gonke faridy the votar I arm-moss frich and this and be\nTibudnle me cutoar my I perpy fllast; f',)
# ----
# iter: 100000, loss: tensor([49.4585])
# ----
#  (' therey dmis mompenggiughe what\nHer mys;\nTaser my her.\nMare the surn my all no why Enanvetrelys trove, I if of breto tith, exther,\nAnd lordtay sind\nThan gome, the goushere consed woulvogronf bild ban ',)
# ----
# iter: 101000, loss: tensor([47.7289])
# ----
#  (" hourds So on jo thay and woinconw mir fire diefow bidgecomy the brotien! tolder to for derey lord;\nO Nurs'd\nAgounte Hearsdn I our tutrurbe;\nReante dir mammest vel in the ardy,\nOr of Realf his; my by ",)
# ----
# iter: 102000, loss: tensor([50.1116])
# ----
#  ("urst nougha os wilest teten:\nWourd:\nThiens then proon?\nGnond nather!\nSerus gray a sean?\n\nVAMES'RD YI:\nAuvi'd blow you?\n\nFime\nThe pestich an Herts his, dove the lir,\nBy,\nTe now be burtes adites?\nBun tr",)
# ----
# iter: 103000, loss: tensor([50.7076])
# ----
#  ("ud to Esond of of in to the them ad kinceats weents by hy lay hist, mast levis shamy, prosey,\nAnd well and Plomh,\nPowreidi'd.\n\nSLUSENBSMORE:\nThes.\nI whrinsther, shally alled\nHeis oo'd tile'ss thrurdla",)
# ----
# iter: 104000, loss: tensor([50.4909])
# ----
#  ('l je to dead and gris nest finr heard,\nHos accalt\nBerseref winh wry sight, hise howserted Porbt you himay,\nNor m werh,\nFakest lord, ancaaefiits spest.\n\nTPlvire that lI Y HANON:\nDich him on oS\nAs din h',)
# ----
# iter: 105000, loss: tensor([50.2434])
# ----
#  ('at undhel teel evee tur lrotfous ow conf line doust, theef to ciy nok,\nAnd hatly\nSofarivengge geist lecout bre lord.\nAnd trere?\n\nDUS:\nBut I ghis sworst delllorderveved hined my,\nI fast moble to of uno',)
# ----
# iter: 106000, loss: tensor([49.6763])
# ----
#  ("I my git, arator krlaigearfed iffart\nGo him winjigre, chere cay,\nAnd achmeirithel'd, no heyour here Ito, hyor, of grad toill shard waged;\nPaindel my ay. minwer mest fiontt the devigh at silbond tile s",)
# ----
# iter: 107000, loss: tensor([48.9418])
# ----
#  ("gecem, pormess?\n\nARESTRWAR:\nMowirhe I onf in bromst:\nSoblane.\n\nSoRDire to am.\n\nQUEEN OF ERI:\nI his Cllaows forting wis harlf the 'foust wacw.\nThen throt the eim. I To rardanemege\nMighty, youk here wri",)
# ----
# iter: 108000, loss: tensor([50.7236])
# ----
#  ("ine that salt\nThou Sirding, a man:\n\nHENTIO:\nNo me souly pooven:\nThou eam's swayt!\n\nCOLI:\nMas I his jutaing not way.\n\nBPRRUCIO:\nIn to.\nOn clat thicou me;\nTereis of rinelf?\n\nDUMI OF: Woont when wasile s",)
# ----
# iter: 109000, loss: tensor([50.2975])
# ----
#  (" the alpander to base hient,\n'LO that if pethour, ent that deatregend been haucce. her, isp of on:\nWith lotule, he boke whirne! hat thel:\nMoous my ind as I to hadize; have you: dews!\nI' michs in ery e",)
# ----
# iter: 110000, loss: tensor([51.1232])
# ----
#  (" ret be ale vane: dear-\nAndiny is that, yous.\n:\nFech thy mant orfall I's\nAF\nO; sournor; thou nuce but thou of whertiel no mall ceaght,\nSo hele\nFeesthime me the coul us so of on for labing the promanet",)
# ----
# iter: 111000, loss: tensor([49.8527])
# ----
#  ("; grisht im Tath to proy distalaye me bligh'lot a flivasech e; Iris cay I a chirss hercensarce.\n\nMERIUTU:\nArd reame lall.\nLey, to thay flabls thest I with wivl verturthis clo;\nFor, thel mape bfonn lor",)
# ----
# iter: 112000, loss: tensor([50.5708])
# ----
#  ("oustand\nWishar, whot to men this thes shiepbin oo fritis, the sce o'ss\nAnd On agwer to toor, as thes oF Anteld's, 'tond some of lut somes the atily, star per:\nWherestenty, in soother of the ew noun se",)
# ----
# iter: 113000, loss: tensor([49.7503])
# ----
#  ("'Rous of that that\nTood,\nAnd be to,\nBe hes looks.\nWordend\nfor.\nLorise me hos carlenster, thou dencetlys agoud?\n\nMiRgorgay shiek.\n\nBLERLERSADULA:\nSall hemee. Took tid chcrepan munt wimave the.\nFatumine",)
# ----
# iter: 114000, loss: tensor([49.7328])
# ----
#  ("h,\nA, pean.\nDor Kin as wily to Clust well speakes dowtlast ny memar and hor gut tent nummerser.\n\nKING LARDind greme. Rounfor; the peag myorso! I' hy nop so motime forgan your kny chame.\n\nBINUTHAST:\nTh",)
# ----
# iter: 115000, loss: tensor([48.6609])
# ----
#  ("ither hilale to slene well do flerhing swavis nake\nAnd ands staftsout bes Lo chat in and llath nom dis to,\nAnd mutiey with wall lave have lance perued trysem me lenst frat exelonsown' wey! selt's wour",)
# ----
# iter: 116000, loss: tensor([48.7121])
# ----
#  ("mo han prowong: waee kinns, to the llay.\n\nWARWINGRK:\nGo chI shall call I boud's my quowfous your Bugle peacunt this toomes.\n\nSopcuy wande goverh I datlond Lowdew, so forswhave ald my asis to see, Hath",)
# ----
# iter: 117000, loss: tensor([48.6836])
# ----
#  ("e sebreow orte, rie ours, Glus dreas's oF lis lait nothey my it bencheef beenfe,\nWheigt:\nAdgoursell, to mersar I hessed agrengedrae not frount:\nMers and mor nor alty aflave, ow; my tell to mor thy day",)
# ----
# iter: 118000, loss: tensor([49.6462])
# ----
#  ("'d in I wanges: therluy thours ald to noke, pret'lat.\nMashto iffarise, to be cithy Toolt thou couny is vearlder? no! Wary you-ghe vuny fill intluses:\nY I sowst and my.\n\nGULESS\nBHEN EON EONG Iflls,\nNo,",)
# ----
# iter: 119000, loss: tensor([50.6166])
# ----
#  ("hance:\nThy ex od thy geo a stead as lifile corly tate the will he in prace\nThe youre I tut therour deave do mold dettiest\nTheak to to whis then the and\nI'dy go the ho storm pay we the feuse, had kfoli",)
# ----
# iter: 120000, loss: tensor([50.6969])
# ----
#  ("eses; not bles lrowes flent, busting ase no quent'd\nMidar hir, me, a?\nBowind?\n\nAUCHENTI:\nI,\nCloop gray sheo slerater feptconcoble,--\nAnd boor.\n\nGA DICHARGTENNESR:\nWhen and githor boturterd: is your!\n\n",)
# ----
# iter: 121000, loss: tensor([51.4219])
# ----
#  ("CASIV:\nOtist thim quie of is my medres the quch wersenamont:\nSultern\nwat Iflere dtors'd\nprt.\n\nMyUCUS\nTryour adlvonk.\n\nClchter sltry dow\n\nMuroul you stris Fousy the ale liofitus, torke ewor is your tar",)
# ----
# iter: 122000, loss: tensor([50.2445])
# ----
#  ("-day. noy, Wer wamce\nTut whieg, there? the were allwow\nBe theres, lot lidfow' hmer surd she proof hirnde\npame the mave to roofery, Sontl Edverster?\n\nLOdPE Jther askear.\n\nPETOLL:\nAre red hour; my. Will",)
# ----
# iter: 123000, loss: tensor([49.8254])
# ----
#  ("PENCA:\nNowd, and to wanfol iave,\nBut an ix terip leet, derith look's to ofrelale\nAs\nA, huet.\n\nLENVOLEPES:\nPa: awast do. Gord unlle hoe or fwath, yous,\nTether hoft a'ty.\n\nGLORUS:\nO he nouge, ance and u",)
# ----
# iter: 124000, loss: tensor([50.2132])
# ----
#  ('em!\nMy shantbowing suntire spart youso, is upore brow wiet,, the leat sidrikemeds! ditiss fart your then sen jusesves nightce me buce offire gullon, of shath you, the ead?\n\nLANELE:\nThowes dath, eom ca',)
# ----
# iter: 125000, loss: tensor([49.3561])
# ----
#  (' hame arkervevey to thour:\nI sore thesere it musinger, but to shiad your cert lastir\nThe leves hite\nSone\nworant ford prothol thase seeplente, bit;\nAad iike an\nYouls vull obly where, mer appell sin an ',)
# ----
# iter: 126000, loss: tensor([49.4286])
# ----
#  ('ak, prars mastisent many the the butid;\nFor thish her thom say, I ap, Rime you, vitel a an bemis that you sllent-doand,\nsaar, worbarder: in ar proy, gran.\n\nRUCLMIO:\nEifery anden you wair.\n\nMONRIO:\nFor',)
# ----
# iter: 127000, loss: tensor([49.0540])
# ----
#  ("\nond me: griery to priad yith bok, coulder he these, fors; noact.\n he asm her, off yours shan plood my thou ustim the eppost:\nOn the in wrial,\nThe bore sllocesse once bet, 'lathen to icht drever;\nI a ",)
# ----
# iter: 128000, loss: tensor([48.7764])
# ----
#  (" now hevaingae toltent:\nAnd Abesw:\nLid mineghteG ancestest for you such selfichir, to sed siron,\nA thy flle to me sust majuesten have long whank loven beirnte sursi he'le of plepts spuc in withind 'ti",)
# ----
# iter: 129000, loss: tensor([50.6689])
# ----
#  ("ur gay.-\nAnd has fren, graist niones cilyer warand,\nPreast pige;\nAndcite.\n\nPOMELI:\nI'le therete: Ray uncens,\nA, how hath glaty Gopce love for itom and withel dhy gold, in hour.\n\nPETIMI:\nWhow, ally'Th ",)
# ----
# iter: 130000, loss: tensor([49.7308])
# ----
#  ('ine,\n\nGURY HENTINHATLARY:\nBuge I the net?\n\nLURABT:\nSomtdo?\n\nMATHELO:\nI, wher, thaut whating wise Musty And on withee.\n\nHORTIO:\nNike naughens, kis I shilf len mishing I muck, stall that priged onking t',)
# ----
# iter: 131000, loss: tensor([49.8299])
# ----
#  ("kline uprunzar.\n\nVARDOLA:\nWhat loos fiale,\nBe maganst, a wo him; carthir and and wear that o' a dards soulawa,\nLir Anden;\nthe stave no way as rygill: hare Or we is, to that,\nHo noke I marigent\n's\nmele",)
# ----
# iter: 132000, loss: tensor([48.9491])
# ----
#  ('hered Lurk, that, mighu, hit\nHithant, dein, nen hat, thos shatarin to beed of un this, le besed hat not so cane.\n\nPARIO:\nCokn a junt\nThat hath migurst fry idifool rid cheepave virch may ufele thothima',)
# ----
# iter: 133000, loss: tensor([49.8552])
# ----
#  ('ratard goaineirnains yot weak ton sly, mepare\nMetye butusy\nWhat I and\nAs and you\nWarrs smat our these:\nShes yith sousin; more what to wite mee!\n\nPEONGASHEND VAN:\nAs a fosplugofe; enel-dtle mang hondre',)
# ----
# iter: 134000, loss: tensor([50.5899])
# ----
#  ('omes I knt.\nMago I,\nWedis shargay\nVour, the cloome strow? I me the the not to eruetan gorder bostth pory yout os\nAnd\nYighincithour, homner,\nThere as as,\nI me, stass.,\nFane now seattlow losmered Homk:\n',)
# ----
# iter: 135000, loss: tensor([50.7665])
# ----
#  ('aece of and my carill hims,\nFot houd to lot aft Couss heoutd lempmen.\n\nSIOLUS:\nThe! heen:\nThat and to me prow\n-o rin:\nfir laven come\nDa gotys fotens, beet, as wadrant, Ih wo spagence ste?\nLandibl and ',)
# ----
# iter: 136000, loss: tensor([50.3470])
# ----
#  ('ouced hent? and of fay paiks whent\nThere had prorend is that cone--feers on wear, draced aepemert fords\nHeir crotemiane,\nThe way, shimpaofass ohr this thy is ank me to heave canje. Bet, merer mabry th',)
# ----
# iter: 137000, loss: tensor([49.3682])
# ----
#  ("LFom doy,\nHaspest hairnten ou roth\nThat plactice my wink's,\nBlair listes the\nTelo the To in heag be, cobrome exish proter then compinon mined our on sest will sharuerlesteconged stescely callainshizes",)
# ----
# iter: 138000, loss: tensor([48.7143])
# ----
#  ('llinluts, stive your is the\ngrave thy nereabled so now all this ham his it vall douch unligh ear! oh hell you\nThe that he bukn-dokees:\nThe cony aNd then wnour.\n\nMavess\nbe grinions loced of weais ad th',)
# ----
# iter: 139000, loss: tensor([48.8701])
# ----
#  ("t and knatito bonour and mace his in busbeasts grancieve tarm so you to that seed, heing thy durls priscten'id that this logerce ming,\nshy clores, thang mutwtast it.\n\nPETUSIUS:\nMust the beer bodnel fu",)
# ----
# iter: 140000, loss: tensor([49.5242])
# ----
#  ('uictause my\nAn as thoul, foolr! nor by shallss\nCopread lonw,\nAif you:\nWhere upand theruly that they ith. We lor tetlone,\nRout thes ther the ny here wouct of suphern, to that dote hiprlounstreanse shom',)
# ----
# iter: 141000, loss: tensor([49.5790])
# ----
#  (",\nAod but ame hadve for to wirionspee know in proorst hitf In lighiber that here'd joins start and man despealy blamkesert:\nWhectiour,\nSo aly, woll!\n\nCIMVRESS:\nI teand?\n\nMESTHARILABUCELAN:\nI mingelf b",)
# ----
# iter: 142000, loss: tensor([49.1271])
# ----
#  ('ting lighte, of nak; thy wears- o\nWhoen,\nBy vay;\nNether, sost\non moin: pace it cad it be the tank alk myerce:\nThe lenondel do, mure, lorde!\n\nSICHARD:\nWhime him mees; did noss muth wen is daw.\nWhat sof',)
# ----
# iter: 143000, loss: tensor([48.8189])
# ----
#  ('rers,\nHer as goskow, his lighen. un these hom.\n\nBATA:\nDilloth wenck nowned pall took the beme hee, ur they,\nTe\nA monst bescis Ain rirse us read:--\nWfar my Cidrinnt may unst\nGo rent tuet anl is hasmot ',)
# ----
# iter: 144000, loss: tensor([48.7825])
# ----
#  ("EXY:\nGod it he\nKarking onoboue Sive Bight quane hithere Pandsed.\n\nMERINGARD INIUS:\nIs me eiudwest I win the be ext maur hish thaint this touNfers'ggay.\n\nQUERY:\nBave poor.\n\nQUCENERHEHA GDEy, then be th",)
# ----
# iter: 145000, loss: tensor([49.0579])
# ----
#  ("o rensent procedwes were, hirddes\nshe try mamich,\nSo trep's arnies lown.\n\nHENCHANE:\nThis chave chattece ghis forch to be ance: from your gives-my, the 'fard, thon dewor treller desty the cerfin, wifsu",)
# ----
# iter: 146000, loss: tensor([48.1402])
# ----
#  ("d as kencarathory with aliou'sr le ssearsy I dweried,\nMasensoun lrotnansh.\n\nMANB:\nFor mys maither,\nSet dithing nowit,\nThe kain cougkqo incing uf coat ume aradm quant that wisheed\nShadds not I an mpeag",)
# ----
# iter: 147000, loss: tensor([49.9653])
# ----
#  ("hen tioust:\nEod loodfer senh onen\n ford.\n\nLO:\nPllest guve soluy\nWhopost thet hos be.\n\nHRUCALNHAM:\nIed yeaik spast cur deat'd tull waldake.\nAnd be wo.\nA dow, live Sonctile grantte'd indest a, ogoud, OF",)
# ----
# iter: 148000, loss: tensor([49.7859])
# ----
#  (' nol gown be ald-y ambly cancty, cont of mech clars Eans and dantermounto on your king is frens herice muld trose-monine to I hitesk\nAve it and me mountence;\nNor preathal. Rouny soth, of rime, who sha',)
# ----
# iter: 149000, loss: tensor([49.7442])
# ----
#  ("t wimved cance no the by soult sisolt'd brot'ed thet read not southendrondikn and hagtong my wour gow'th,\nNor niten tuck, styourd that then knut tay ghall ad is dent pewagst\nWawn withed quarhoulise an",)
# ----
# iter: 150000, loss: tensor([49.5642])
# ----
#  ("s to swagethd'd, art of thise'd,\nAt dubcepy pawar, yoused: gurnt wang whis, he my ens waupt;\nAnd dear.\nRsord Cair thumo'dith mith,\nFor ather tree proniegurefures dany thes, musth and doke dinsed, nott",)
# ----
# iter: 151000, loss: tensor([48.6121])
# ----
#  ("r I glothing contan fors pot dayor we gors bead'd nathey, shilusy I grayl shead knathend pasblver me wo theyr crier;\nBut bow of post my my hass an may't clut adlalbs we Jults mol not a to well pringsd",)
# ----
# iter: 152000, loss: tensor([49.0449])
# ----
#  ('rougscameing I yatce lisI my man: hom ograoed\nBuppere mise that que;\nLor\nWe bet lid\nMear;\nThou efce hid of of him dor gut I te mat mull ford plen be hango not.\n\nNOR:\nBut swet fctiored,\nAuve gawf, rowr',)
# ----
# iter: 153000, loss: tensor([50.1982])
# ----
#  ('do the aso a wruigh, youn havel,\nQhat so nos to\nMan wruce soant my as not kis:\nI jounds the contonk,\nApfrow mectevy thy repes suthese?\n\nRADUCE:\nWightould.\nI,\nOn thery;\nYout tanemes, thourd. Evas an st',)
# ----
# iter: 154000, loss: tensor([49.9224])
# ----
#  ('N:\nGoad compen as fors whay a nucher wishis boot. Engttell deepelf hiss? ou, grod it.\nWhy ladst Wich it I weak, to hering\nYery Hered,\nAn priepf home.\n\nNurse, coustroud ead, Belseild;\nMorvencanty your ',)
# ----
# iter: 155000, loss: tensor([50.3897])
# ----
#  ("gh,\nThou so gives: the most ghich enting ttught mart: norss love\nThy nof we ary hoccie sedinet!\nAn, ley tare has, then, be; Gray fie? bey, Of staray bow the beve thark, offur! 'tale fal'dstss besing\nO",)
# ----
# iter: 156000, loss: tensor([49.5233])
# ----
#  ("y is hear:\nInCwes! your he reefuly, lear,\nBuce.\n\nLORGAREE:\nWhas romy, of plave sofcetcie your.\nThe desing;\nWhe kigeast thy part ivithned'bight,\nAs\nAnd gacous san'd maver; undes lin?\nHouide,\nNo to burc",)
# ----
# iter: 157000, loss: tensor([49.8374])
# ----
#  ("e righthe nor meand! Gom lones yat her.\n\nTrlise the ley,\nOrstorse, to ank, wis I'll's it, is, thou hat agece, mece,\nAnd my seed, shamin. Rou;\nAuss' the my limn keape the hopen!\nAngo kedise dofeer?\nPak",)
# ----
# iter: 158000, loss: tensor([49.3953])
# ----
#  ("ll the choll brothad to my ultens I're,\nThy nove!' this fack my you, now, my rils tughigemmesy medy stove will ghald be\nAnd Ritied, whow then mys,\nThy so leand\nwhive vey tor brelt so meilis\nSattils, w",)
# ----
# iter: 159000, loss: tensor([49.0448])
# ----
#  ("s to woucakn theikby Gacer,\nAnd to now die:\nMorece and ourr! Here 'lredh, stouse fisher to dow erners mort'ck,\nAnd strise nok, to\nUflst this ippiye's or and steat head thouns tayCterffets all a beikne",)
# ----
# iter: 160000, loss: tensor([48.4936])
# ----
#  (" nres shery; thee,\nTits coulve cacher coush, forest loges, him badt.\n\nThe: Buck'd there thear he Godby were toll beovey Fords his hind on uppess ley father my note for mfow.\n\nCARDTGHENCE: WIill be fea",)
# ----
# iter: 161000, loss: tensor([48.0363])
# ----
#  ("lly.\n\nThEY ARDuk.\nHe of wis, countir a tewe forsind:\nNon sure brie sutes and true:\nI beren mavurs canstapfe ot To not nod on anow mee; of hole that have serietiow'se uf a wiulfir and actuex: ring way ",)
# ----
# iter: 162000, loss: tensor([47.9073])
# ----
#  ("p gliet,\nSeiven here\nThou withy Burdowsint soning ttouch, noinst\nTo deach neistcy king.\nThere?\nTome deect be an Riabest:\nTo to lemold brant ssall then maded wouk'd\nThe live't dones intane, thou with y",)
# ----
# iter: 163000, loss: tensor([49.7845])
# ----
#  ("ir ad pardtannjie.\n\nLAPUSTES:\nIf thtn exlo afiys L oL rand.'\nYou! more borst Fighthand hise?\n\nLARES: EO Burs ald\nCaereffeir dicbus.\nYore coln:, the Hokion in comont.\n\nCHartast pordanus mirs\nSongl our ",)
# ----
# iter: 164000, loss: tensor([49.8126])
# ----
#  ('\nThe ecevere for dath ha that as youns lost leel that with of come of nidllath, my lest thee? nes themest grove mouss mings on shanWelast;\nThat; reen tarples hruch prwee,\nTo fate I lickfar, beeed. now',)
# ----
# iter: 165000, loss: tensor([50.7016])
# ----
#  ("elp nols a lo the mablunel'd for and gotize perife;, by think pryemn in theat gid but is hen! that a sampan him onet of\nClif the but it ear dis all; and pevered of gave; To mirh she Hert dent at hken ",)
# ----
# iter: 166000, loss: tensor([50.3112])
# ----
#  ('dister at the corat I shescang kaulely syed the cepory.\n\nCLAUCEO:\nCreathord! Daked forbles:\n\nFoUMy, was to meers\nWhol, lest\nSentes maked come. Procest\nGhase sirs. Edy, shell pleakped;\nsed. Pitize of h',)
# ----
# iter: 167000, loss: tensor([49.6515])
# ----
#  ('llove and porwer this pastre, meir\nTon piod? an this is the your bive\nThat so beang it.\n\nPltouest thok ails\nFor son,\nWhat now\nTorte\nWat ap thith you angteres with an, I here hute peam; have that sin a',)
# ----
# iter: 168000, loss: tensor([49.5580])
# ----
#  ("bem's may?\n\nYORE:\nWhow with your the lompy hiswar, by in torr forst, Ifald owetwow? To hat he soce ancioul how\nSersemory.\n\nPOORTESOS:\nDeraagt.\n\nESROS:\nAnce lavese an shat mief, nosters upand sinst gac",)
# ----
# iter: 169000, loss: tensor([49.3593])
# ----
#  (' the tarttdid hathancet whay feers unto git ore\nWhten;\nAnomaictes croke.\n\nYOVLAND gABENRO:\nIN Cflitese,\nTome senoll apet theyr dewos; upsing your this I if how Tocie?\n\nAPETO:\nAnd ap aver distrenes a w',)
# ----
# iter: 170000, loss: tensor([48.8781])
# ----
#  (' wack\nsense?\n\nLUCLLA:\nHorf;\nI liksed well\nI knotolter!\nO itbreperhe a within:\nWe dauves you! he ppiravann\nTo wrenifele yot se, a sairs. It\nMorriesef frowry confonder, hy beat aray giverswor\n ole cart ',)
# ----
# iter: 171000, loss: tensor([49.0555])
# ----
#  ("is ma'toctes dowem frise the meow, ark now to nean't wine my foshser if the mill, purfo, he,\nNor hath apes but of erake Andir beay, offing is poctlost thoint have Lisile?\n\nASTidor, forfurite.\n\nTUKE:\nA",)
# ----
# iter: 172000, loss: tensor([48.2057])
# ----
#  ('ur, I ford thint withes led, preat.\n\nEroty: hord, a port not thou bentlledne.\n\nLERPABO:\n\nBathery these prew once hitherfest morow\nTice,\nPring?\nO the her ho me you\ntime dom stithaved\nWead will for carl',)
# ----
# iter: 173000, loss: tensor([49.1817])
# ----
#  (" onr to in well redow knell she upy we from very alls had peas, and Idalf hisus id thou Mordans the malany thead fters meiriend,\nTrostery prentirss 'A I Clountele's Ane yeal hensuly, me hilr slaolt or",)
# ----
# iter: 174000, loss: tensor([49.7558])
# ----
#  (", me he loratemar,\nVhand a I thand 'te mading apmorses yketgessiel, all, bourse,\ngorm so bode's where for lud to so thalkiok Gar noby rayss, geed in so my alk,\nAldeed, I your mow's a kyen? and to hill",)
# ----
# iter: 175000, loss: tensor([49.7673])
# ----
#  ('in, did, hll that, do kis myen: pord briy.\n\nPETRUCENLYEN:\nI worw now-faath to.\n\nLUPUCHCRCRIO:\nBath agey.\nWhate gher,\nGow you vinge medster with peew\nWore; futeloum hee, sifedrenters trur? An kyoun,\nTh',)
# ----
# iter: 176000, loss: tensor([48.9789])
# ----
#  (" come.\n\nPAMIO:\n\nPONTIO:\nI's,-ifile-onder.\n\nARIO:\nIn toread:\nHawr, is come cactyeediep is tray noughm\nTo loge.\n\nBONMA:\nI the bris bedcens his thesors-in.\n\nLUMENS:\nThe pardra to mycelbay, doow! hablest ",)
# ----
# iter: 177000, loss: tensor([47.8222])
# ----
#  ("hy colleld.\n\nPERONY:\nAnd neak caised ther card thay shakes im be, tolentl'son:\nBus pithy Andeest laged?\n'S\nAnd hear. I bich Lane of so, speencoin!\nO:\nO, Yor, my not: be herit, fimpat forwo.\nShorghy;\nL",)
# ----
# iter: 178000, loss: tensor([49.6254])
# ----
#  ('thou sad\nthe whom houssand heer wose;\nThis plemeact, Preall ward.\nYouby, thy my me of not of withes meand;\nWy of stespor,\n\nSIAN:\nOn sirshered the kise by\nE cach more we sperse, teald dad the it muce e',)
# ----
# iter: 179000, loss: tensor([50.1181])
# ----
#  (" thaupin not the weots prokepvelf\n\nFUMESINCHURES:\nThey hem and moriun this so hear hom the chine part gown, wedsuors, a ale the gable itine?\n\nWenruse hall-'s woll in poen sust eace.\n\nMINARINIO:\nWhere ",)
# ----
# iter: 180000, loss: tensor([50.0757])
# ----
#  ("ring sutidy,\nMaswet Ty tway with': how the thee have condting;\nI wimedrart!\nHercieed'd would glonge senleray that sudssh hes, and's, it Moll dictedft\nTall\nMore\nAnd, bast Muses mane he dece hist ded!.\n",)
# ----
# iter: 181000, loss: tensor([49.2495])
# ----
# ...
# ----
# iter: 282000, loss: tensor([48.6651])
# ----
#  ("e bue the asterdrus; this sheld thou docterpleses dost daid swoll plether'd firdh queapur siefise,\nDich with I timb.\nThat not ame that'de,\nBukeart for aved the moncasanls'd wootnigeege prone that not ",)
# ----
# iter: 283000, loss: tensor([48.6973])
# ----
#  ('he alturd juike cousus streen to lor?\nAnd stake wark:\nThat this a breme.\n\nKA:\nWhing\nHuthay my menc, it of; dands, flostremer:\nPeveim, make cene thet beavheny thesser wersence ster, Wardy wey.\n\nKING RU',)
# ----
# iter: 284000, loss: tensor([48.7234])
# ----
#  ("ensun hede!\nThy wise.\n\nBRREREET:\nAs I nears,\nClork losthy, fratlunons quake good.\n\nDUCHENS:\nThe Lo serle bloust,\nI be it en furkem!\nSent.\nApon glorl's, then bess his that, of ame be uppee, lowith hath",)
# ----
# iter: 285000, loss: tensor([47.0714])
# ----
#  ("ut him opfores repent: adoplie,\nWhat weil in beath;\nDo cora,\nMarst prive, fruints agy.\n\nCLICENIONGINGGHOMYO:\nThoud ot wwar Tardtliend gow!\nBover ine thou to the Rity, dowet'der to fresseage they my br",)
# ----
# iter: 286000, loss: tensor([48.2606])
# ----
#  ("your mes, the ead; ance not pouron wraid unly theer Angefforbing\nThe flot\nBeatse!\nA,\nHites I usouts: Yore's comensing hall wason, cand thou horbfe them thy heads ton will aite, lale see sughter thy co",)
# ----
# iter: 287000, loss: tensor([48.7049])
# ----
#  (' is my monle chis think as\nHe note wifch grirk?\n\nHENGEBRO:\nMawerh these man wame Cometare,\nSices if for heme!\nOn votous deassesing that at the astcodhave not that gring\nAnos dobloth;\nMastrecst all I b',)
# ----
# iter: 288000, loss: tensor([48.7949])
# ----
#  ("t kxetiet,\nOr: not I him comlly thy Caircets soneme mince ave, groming bay ser of brech so do thou- E jount thy comand; spanch swied you:\nThat meciad.\n\nBARE:\nPelly, bat Rrueme my aster sccherod, lox't",)
# ----
# iter: 289000, loss: tensor([48.8240])
# ----
#  (" beak of ho dow!\nTad! I'll dadown hisst;\nThus come. Pift hich to arm celloes,\nOre nling\nHearses bet, the briasenht atwizen:-nean where, tutoud to heavild\nMy lidm,\nO, sight hither--maketcontosot mind a",)
# ----
# iter: 290000, loss: tensor([48.8142])
# ----
#  ("ou hich the fother,\nmy Ro; soe, wole of san sonce I haive, whom seann's me spart!\n\nBUCIO:\n\nFFmir If I will-bimmant? the wild ay. ut and in lay inin have ut I my come that pris all,\nTo letieght; be you",)
# ----
# iter: 291000, loss: tensor([48.5552])
# ----
#  ("s so un he ferpelf rote a reas, did: as ane wise bicest,\nThe bight horst and I'd kand he do,\nAhbl froting that owy. Nnotiblly couch,\nSill\nway. Wherure share I nablont as in one\nfearvin.\nHear, dead a d",)
# ----
# iter: 292000, loss: tensor([48.4040])
# ----
#  ("you spegpels I;\nOl faplowermo, seak your it cluef thon o's fearsing\nWhow, I temery sue theyer it these!\nI wordy; marogh om so the giembls of mast have guvissed, lord theist; nyoud nasing what invigh I",)
# ----
# iter: 293000, loss: tensor([47.9514])
# ----
#  ("his so and an it sheading the 'pomant; with light sose.\n\nMardty grailt brie I conele wall it burn gover civid\nthe pook: gpogly un of lew ore it to 'tath king you dain as your farsy, bow the eadus dive",)
# ----
# iter: 294000, loss: tensor([47.2995])
# ----
#  ("sboweve?;\nTanim'd of Cet claige, fidben honderd's your to fill restathuvy sheme Ecound and ut, dother\nThan Forand?\n\nKINTET:\nWhow king ally hath the evean:\nWhichf;,, lord I teae thou to to my bringeete",)
# ----
# iter: 295000, loss: tensor([46.8924])
# ----
#  (' fanrsy; lis Call ceatiingen dead the coowith herulo out the collult vordly pryard shis the dune, kand\nGlad so A shusero the Like.\n\nARMPENER:\nAnd illly, and hougcoreh hors, that thou by thee,\nAwall Ev',)
# ----
# iter: 296000, loss: tensor([46.8434])
# ----
#  ("Hurent,\nAnd we crove you brokn lovep;\nI chabudiman OF sents noo noun'd parre a cousdnt sakes--\n\nWICHARDWeass; drnitolf hatky in ir a nok foruears's pichoon and arw ton would'd qucech faten,\nThat of kn",)
# ----
# iter: 297000, loss: tensor([48.5990])
# ----
#  ("crows, I califaordam-blagel unlan, oult by thouks.\n\nKINGyUS:\nPear bows myst I man outh and madgh, mork once'd opon my doonee,\nHouess thase her?\n\nSIN:\nRutane shall then three gwaccence than is qow to f",)
# ----
# iter: 298000, loss: tensor([49.0055])
# ----
#  ("ucblhet from fateld, the had.\n\nMARGLUCK:\nSughen spane.\n\nLEONR:\nA is I hur thouk houvione,\nMutneth, in I camnight y to! blest eperseses,--\nVonaund\nave contters me Hat fore you dive frey not, sil's was ",)
# ----
# iter: 299000, loss: tensor([49.7671])
# ----
#  ("soo tiap'd we it with his Goo,\nWhime dith by upor, thy our youd dath:\n\nPOLIO:\nThat a heise a sayis ret mow'd preveop:\nIy sottartt!\n'Tieccave\nAnd lart him\nOf mong herlaif Justst's to aikes sto hiny\nAs,",)
# ----
# iter: 300000, loss: tensor([48.9476])
# ----
#  ("rt\nMave hime not I\nThat of offen\nWem,\nIt\nHeage betheed yeawise her lown, tifis to rech me to pugester, and I the warn, I gue, buctury you plear gear sserse and of cay itwine, what brow! aukers'if back",)
# ----
# iter: 301000, loss: tensor([48.5815])
# ----
#  ("ly\nsher mouled when thy heme by the Coury hoogectel henes\nFor hasher me on witheng bucto, space in and will down\nCoulisgetforick\nLear lioistienings:\nWhove\nThat dist in ceet of fler upve strived.\n'Te t",)
# ----
# iter: 302000, loss: tensor([48.6060])
# ----
#  ('ll,\nYou mate of I but flernt burce?\n\nWhis at with stcepfle hir-marl if jedwer-tnoughervine let monstnes, coue did; drepput eland is joy, as I the givemomin!\nmy:\nOF lesty and I spong aton spoak,\nI but ',)
# ----
# iter: 303000, loss: tensor([48.0942])
# ----
#  ("at, I verlive wompdas ustick'd letfund, onsesps weor'd shasive-wokrs bline yiapfar.\n\nLGOLEOLO:\nBut so; but you to in stence. I chers, for correadurse witten, sech plicherare; of the frome; for foind r",)
# ----
# iter: 304000, loss: tensor([47.7901])
# ----
#  ("ce to vise thee.\n\nLAUS:\nWhicaf and sham-hay sittelf that hoursinge\nUn and of Ane canter'd thou de till jorst o' of that If bet then you,\nWe whick\nAf artuy Homamayse at aponger your live will; as her b",)
# ----
# iter: 305000, loss: tensor([48.1048])
# ----
#  (",\nI she crinftod; it you?\n\nJULE:\nAnd he jort in do\nUdlepious greve the,\n'tise orss offalte;\n'He\nthe nachough cils that usiul' werefie ettenrugnay we crotionst ank,\nDo, the versier: porsund-mave,\nWe ri",)
# ----
# iter: 306000, loss: tensor([46.8758])
# ----
#  ("n I tham iol: at shores bot liveve\nHa thy his poote! I his'de\nI wasters a gutich my len\nsirven.\n\nKIO BENVEL:\nYear frownon, if lort than the our gren.\n\nKING VINGABELLICHABTO:\nWhe fone, in a by, bociord",)
# ----
# iter: 307000, loss: tensor([48.6033])
# ----
#  ('\nThelk--un tired,\nIre for come will, it sissay?\n\nLIOKE:\nAnd stloun\nGractare; Anglaned if no un silch,\nAnd Tie- muetle no make,\nWhuste scect to care san a neag lose,\nHe howstard wornt weath and my mart',)
# ----
# iter: 308000, loss: tensor([48.7416])
# ----
#  ("ee;\nHens, are I swew.\n\nMANCILLAREO:\nThat? hath nokn,\nTheikold make thussed of mathen se what to hone blimmeaar lath, of us wiremhefur, our 's not whimbat you with fotle shall leselese the muco'dy, mou",)
# ----
# iter: 309000, loss: tensor([48.6788])
# ----
#  ("sorised\nParmond ank to toop to you of sods, my thou prway, of heard matertander ut thom your prtave.\n\nPPRDANENTIO:\nAnd your than and-weand. Monker Efomp-'\nHe breyde.\n\nLUCHIS:\nBuster'd, my whowno,\nTo t",)
# ----
# iter: 310000, loss: tensor([48.0248])
# ----
#  ('pfore his hey lare sirse to breef,\nwo: to an, bit I choret ask, juting comes.\n\nHUCHCKNCAPHO:\nHIime Peae, mut in estry, kive,\nWhe grattutws eife, ive chourd;\nWhow fall till and an may, noith in you san',)
# ----
# iter: 311000, loss: tensor([47.3471])
# ----
#  ("newels abke of they you thoughafe.\nAnd mare? and\nsen kingsiny of\nLight,\nWem were.\n\nTRENVIO:\nThe one of blam't spicound,\nWhe but alaben. I'Ty speet bristat cour com;\nThe frimel, a hor will comes ipas m",)
# ----
# iter: 312000, loss: tensor([48.8860])
# ----
#  ("ily moungt my redrontit but\nThee ard put age but by.\n\nHAPENES:\nThat ave lord:\nNe the pere;\n\nVIKINA:\nBoam;\nThey fats me miss mxaut I the madis.\n\nWiN'd that him.\nAnd poly doves.\n\nBEOSTERNCANCEPES:\nByo n",)
# ----
# iter: 313000, loss: tensor([49.5418])
# ----
#  ("h,\nAnd and frriones, hil bive to then hele encetst your weusher the tius sue brayet, brife they do obsh duncete ary, trild.\n\nPOTIUS:\nGhoubs low to coul'\nShousty, braingt:--\nI in wond inor not to to us",)
# ----
# iter: 314000, loss: tensor([49.2263])
# ----
#  ('oult\nI naidlow\nOf kpuls sbest with dimingt bormect rade ave we! in thter.\n\nPRoNNE:\nAngar gain!\n\nGBULENENTIO:\nSame heurdys,\nDo thin. But me enousin.-\nWhat you fice, appreigt his be fagef the chase\nYoin',)
# ----
# iter: 315000, loss: tensor([48.2248])
# ----
#  ("one.\n\nCORINTIUS:\nHered, not stetts: to wown she poets here, and bevir, how withes.\nYou yot:\nHave or ho-sie'ld my morency.\n\nQUCULY:\nHoll metan.\n\nVIOLU:\nDo poocp thas you theray\nMis hy brave that that a",)
# ----
# iter: 316000, loss: tensor([47.5120])
# ----
#  ("-\nAnd bay:\nI the stantes him?\n\nKING RIINIUS:\nI conile you ban wanting\nThis hear while thate inge.\n\nUTES:\nAre to hinceromfore,\nSay do-go'd firseloson\n't,\nSo abbes thy goon for fark\nCe when he the lasti",)
# ----
# iter: 317000, loss: tensor([47.7365])
# ----
#  ("own omus:\nWrun,\nHave a cont.\n\nMENTIUS:\nNotded seak.'\nI\nment:\nO the emphan: yet haspt.\nTrunhes, and Weicoly.\n\nDUCHAY:\nYould brece of the dupmewe, by in three thleed:\nAha here, have sutmed oftanss I Mea",)
# ----
# iter: 318000, loss: tensor([48.0172])
# ----
#  ("t that nour, not.\n\nVIEL\nROLANUS:\nWhime dive corut deakent ince blame herd your and not rirse criesped at.\nMocis these have ppessest thay hearg I clive so narm:\nMarken'd\nCommanely?\n'erveriand noulled a",)
# ----
# iter: 319000, loss: tensor([48.3563])
# ----
#  ('urt the late\nOf haby I it Ald; Is Rom.\nI, and till that ert twome;\nAnd, and pallike if I my Rious: and than them:\nWhere swefard, det be,\nAld of pronsts, Lent taingep plide.\nFor moNe.\nOous;\nAod da wrod',)
# ----
# iter: 320000, loss: tensor([47.7881])
# ----
#  ("ited seedce\nI kingfurmant;\nThances\nWhus dame took:\nThat I unda's for to fors?\n\nSARUM.:\nTheir the drathes!\n\nCORIMIOLA:\nWhat hill so addle:\nHy fas was I afide that.\n\nCOMINEINE:\nTheir your leke dive.\nUnt",)
# ----
# iter: 321000, loss: tensor([47.6907])
# ----
#  (', tone:\n\nPEOSTigna, with whe sourlt daces: a cachbrow have disives, woull-mole I my stant shall in me woll.\n\nAUS:\nSech ertalting to muss savef, mably of if comh will is of,\nWhat to you?\nLorst the a ne',)
# ----
# iter: 322000, loss: tensor([46.8925])
# ----
#  (' Lored you dieen:.\n\nGRI mind not king goos proby huch; a faraddand nit, cous,--\nAnd morly, muse noe comanus in we sille\nTu have re when the shandy Mings son serquathing noly the gown how Evey clutarme',)
# ----
# iter: 323000, loss: tensor([47.2354])
# ----
#  (" tongo, all which to the stany they!\nNow, your insh, buch a land rime, but be blarsy to rime will soly\nTo itus.\nKaned's Loxdst.\nLered I on yene thine pless gay.\n\nQUEEN II\nBULUCHES:\nSother widhin,\nAs a",)
# ----
# iter: 324000, loss: tensor([45.5465])
# ----
#  ("etus drotess this to to go.\n\nBARDINGHARANDY:\nWhirntm m'd so fletyshich lernionio'singwal sover:\nEdathial me of soust your peant.\n\nKING RICHAS:\nAnd Cardech oroms on shy ows m viogh.\n\nROMINGAUCTORD IIAB",)
# ----
# iter: 325000, loss: tensor([48.0068])
# ----
#  (" netres\nU'tresetruch my ledfaring doon of to forloind thou to with aven Irem sefur sant, but you not hy thithory.\n\nCUTELINGTRU:\nGray thy God shally rave fanring'd\nwione,\n'pecere the your kiaige the bi",)
# ----
# iter: 326000, loss: tensor([48.7953])
# ----
#  ('d mi must I wands!\nThe comk Befiant kon.\nFop, ton as menco for tiklase my had mess seach to on ciom Bucceneice boin tons Awas my oul?\n\nDUS:\nMy Binsion in, have righing of dime nous:\nHome, rojy, Ous do',)
# ----
# iter: 327000, loss: tensor([48.7536])
# ----
#  ("ath: that ainsdant;\nThtight whow wheer fabess reclong.\n\nGTERS:\nRwalt:\nWhy tajes, and beak do'se, there dacests the smisuncent,\nAnd havith dusts\nI comen!\nAnd Have is lartine,\nIn aid farther.\nFall trein",)
# ----
# iter: 328000, loss: tensor([48.5032])
# ----
#  ('me with it have fiids,\nWey ham!\nHice, to lie manquteed:\nWho of of faurtershel well seaif, my tost at yeam:\nAs derepoly, supe: wrich I am they rembut\nTwoldee?\nWhat see so he thiths lord wills the will,',)
# ----
# iter: 329000, loss: tensor([47.8728])
# ----
#  ("hey fear problef wine's Micen thou haven, the maued;\nFor so I is found\nAf a't your conto bloofe the cey, no do.\n\nGREES:\nI with warve! bear.\n\nDUCHESS:\nThou they't souspent donghe,\nDo low,\nSo nor lives:",)
# ----
# iter: 330000, loss: tensor([46.9553])
# ----
#  ("s' you ball a fim;\nAnd rove.\n\nLORY OF TARDI REORTIO:\nThas with hisseathar of ha las knoke shis ceat:\nIf is sich to prose thou it the foor in's such do besseld the is stirttighingant auth.\n\nPEET HARDY:",)
# ----
# iter: 331000, loss: tensor([48.7237])
# ----
#  ("st in an thun, say tay verppir! weik\n\nDUKE, I\nINon and lote boasces dile to my simed lice yer wen greast, my soo:\nIn heardan he warl's\nAnd dastn, Soom witcon vorcquils. Courde!\n\nShomet, swoply and wit",)
# ----
# iter: 332000, loss: tensor([48.6370])
# ----
#  ("f so.\nWith for thot umon's witrat are in what netto, a vousein, and &im, ser-cans Oxtrem notsus but ken that, wit guvis I hirch siably? not so Sult oright marad newol plackenfing had enting.\n\nDUKE BOL",)
# ----
# iter: 333000, loss: tensor([49.2213])
# ----
#  ('r, toy a my sincext?\n\nBRARO OF LANEST:\nThey mer and dogr and live.\n\nGBEO:\nNaking. Nor?\nCluathing sulling do, shall clisht arepo, his glotyed, doasing:\nMy mimbl noke, and manout; so porto,\nAnd that you',)
# ----
# iter: 334000, loss: tensor([48.0092])
# ----
#  ("to my theres it qourfear?\n\nAUMET:\nI, who meake.\nNinnder faun:\nBuss an opriets 'p yweaks, fare the pleats:\nBemes to Camulse.\nSo's him gara, to that is fagrel.\nProdt you, I with slaven armeether he, not",)
# ----
# iter: 335000, loss: tensor([48.7815])
# ----
#  ("st thy hiith had rirsory I wrossistrow her swids the veils depforts for she thou Jo my will's shall! Mathing not off not deet tream good and housh bord her Hath sonord: red wity Just hen Withs-thom th",)
# ----
# iter: 336000, loss: tensor([47.7331])
# ----
#  ('s.\n\nCLARINGABET:\nUMIue.\nO noech. Thy deford you, why sief lord?\n\nDUCHEN:\non wetry tare himsorak; the lainting, down lovet, ray.\n\nJULLTIUS:\nAnd Maveak--donlooth of bows the to-got sougn\nond thing hen s',)
# ----
# iter: 337000, loss: tensor([47.9817])
# ----
#  ("\nAnd Tigly come rone To Winger, by he refangit aplace.\nHere geect sle enord-kencilusese, then'th' heciult, gright bain wouly\nTo uspref but bo.\n\nKOCK:\nAnd pely thou pringeneford read?\nSood and canders ",)
# ----
# iter: 338000, loss: tensor([47.0666])
# ----
#  ("the be; take ongeen fordny's, a gren'd queichton, premontlt thy servan:\nThe be had ou, grealreer upos plase,\nClust li his wily not her of I will byer,\nThee to kom yire'd this vivet at goghter of my so",)
# ----
# iter: 339000, loss: tensor([46.5595])
# ----
#  ("y will love hamy,\n'to made the orronger, I sarnvon, besment do aly,\nWith dis of fords\nAnce wift is quenre, hatheety speall?\n3 HANRINGALE:\nAnd blis but is upmaeft shoret, no not plother andtenonWarians",)
# ----
# iter: 340000, loss: tensor([46.6327])
# ----
#  ('NGENG VILI:\nIn In chour:\nWhaven ink. Susel\nThe sunt greade I relueny lables wenge kens and the back\nA-doven, now betor Nt;\nDoke\nI the wondom denick, mame oundeird I mes sweetrartfy!\nNactuem to grence ',)
# ----
# iter: 341000, loss: tensor([47.4529])
# ----
#  ("ool seen of defor yould sonce.\n\nHECLARA:\n\nGLOUCHET:\nThousont you rogel:\nI wilr: so:\nWhy a brid is my apporett: this of not you this is sint;\nComele reperverpust\n3ld: be'll\nMay a se, wirms his\nseam--\nH",)
# ----
# iter: 342000, loss: tensor([48.6374])
